# %%
from pykoreaqi import AirKorea

# %%
aqi = AirKorea()

data = aqi.get_all_realtime()

# %%
data
# Out:
# [{'DM_X': 37.564639,
#   'DM_Y': 126.975961,
#   'ENG_STATION_ADDR': '15, Deoksugung-gil, Jung-gu, Seoul,',
#   'MEASUREMENT': [{'AVG24': '43',
#     'BASE': 100,
#     'DATA_TIME': '2017년 09월 25일 09시',
#     'GRADE': 2,
#     'METRIC': 'PM10',
#     'VALUE': '44'},
#    {'AVG24': '26',
#     'BASE': None,
#     'DATA_TIME': '2017년 09월 25일 09시',
#     'GRADE': 2,
#     'METRIC': 'PM25',
#     'VALUE': '29'},
#    {'AVG24': '-',
#     'BASE': 0.1,
#     'DATA_TIME': '2017년 09월 25일 09시',
#     'GRADE': 1,
#     'METRIC': 'O3',
#     'VALUE': '0.014'},
#    {'AVG24': '-',
#     'BASE': 0.1,
#     'DATA_TIME': '2017년 09월 25일 09시',
#     'GRADE': 2,
#     'METRIC': 'NO2',
#     'VALUE': '0.046'},
#    {'AVG24': '-',
#     'BASE': 25,
#     'DATA_TIME': '2017년 09월 25일 09시',
#     'GRADE': 1,
#     'METRIC': 'CO',
#     'VALUE': '0.6'},
#    {'AVG24': '-',
#     'BASE': 0.15,
#     'DATA_TIME': '2017년 09월 25일 09시',
#     'GRADE': 1,
#     'METRIC': 'SO2',
#     'VALUE': '0.003'},
# ...
